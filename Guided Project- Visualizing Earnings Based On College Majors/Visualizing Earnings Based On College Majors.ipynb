# %% [markdown]
# ### Introduction

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv").iloc[0]
recent_grads.head()
# Out:
# Rank                              1
# Major_code                     2419
# Major         PETROLEUM ENGINEERING
# Total                          2339
# Men                            2057
# Name: 0, dtype: object

# %%
recent_grads.tail()
# Out:
# P25th                95000
# P75th               125000
# College_jobs          1534
# Non_college_jobs       364
# Low_wage_jobs          193
# Name: 0, dtype: object

# %%
recent_grads.describe()
# Out:
# count       21
# unique      21
# top       1534
# freq         1
# Name: 0, dtype: int64

# %%
recent_grads = pd.read_csv("recent-grads.csv")

# %%
raw_data_count = len(recent_grads)
print(raw_data_count)
# Out:
# 173

# %%
recent_grads = recent_grads.dropna()

# %%
cleaned_data_count = len(recent_grads)
print(cleaned_data_count)
# Out:
# 172

# %% [markdown]
# ### Pandas, Scatter Plots

# %%
recent_grads.plot(x='Sample_size', y='Employed', kind='scatter')

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter')

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter')

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter')

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter')

# %% [markdown]
# Question: Do students in more popular majors make more money?
#
# Answer:

# %% [markdown]
# Question: Do students that majored in subjects that were majority female make more money?
#
# Answer:

# %% [markdown]
# Question: Is there any link between the number of full-time employees and median salary?
#
# Answer:

# %% [markdown]
# ### Pandas, Histograms

# %%
cols = ["Sample_size", "Median", "Employed","Full_time","ShareWomen","Unemployment_rate","Men","Women"]

for i in range(8):
    fig, ax = plt.subplots()
    recent_grads[cols[i]].plot(kind='hist',rot = 40, title = cols[i])

# %% [markdown]
# Question: What percent of majors are predominantly male? Predominantly female?
#
# Answer:

# %% [markdown]
# Question: What's the most common median salary range?
#
#
# Answer:

# %% [markdown]
# ### Pandas, Scatter Matrix Plot

# %%
from pandas.tools.plotting import scatter_matrix

scatter_matrix(recent_grads[["Sample_size","Median"]],figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f53355d5dd8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f533565ecc0>]], dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size","Median", "Unemployment_rate"]],figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f53357c3ac8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53358adef0>]], dtype=object)

# %% [markdown]
# ### Pandas, Bar Plots

# %%
### recent_grads = recent_grads.sort(["Median"], ascending = True)

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False)
